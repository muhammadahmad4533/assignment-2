# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/NCHS_-_Infant_and_neonatal_mortality_rates__United_States__1915-2013.csv')
df
# Out:
#          Type  Year  Mortality Rate
# 0      Infant  1915            99.9
# 1      Infant  1916           101.0
# 2      Infant  1917            93.8
# 3      Infant  1918           100.9
# 4      Infant  1919            86.6
# ..        ...   ...             ...
# 193  Neonatal  2009             4.2
# 194  Neonatal  2010             4.0
# 195  Neonatal  2011             4.1
# 196  Neonatal  2012             4.0
# 197  Neonatal  2013             4.0
#
# [198 rows x 3 columns]

# %%
df.head()
# Out:
#      Type  Year  Mortality Rate
# 0  Infant  1915            99.9
# 1  Infant  1916           101.0
# 2  Infant  1917            93.8
# 3  Infant  1918           100.9
# 4  Infant  1919            86.6

# %%
df.tail()
# Out:
#          Type  Year  Mortality Rate
# 193  Neonatal  2009             4.2
# 194  Neonatal  2010             4.0
# 195  Neonatal  2011             4.1
# 196  Neonatal  2012             4.0
# 197  Neonatal  2013             4.0

# %%
df.shape
# Out:
# (198, 3)

# %%
df.isnull().sum()
# Out:
# Type              0
# Year              0
# Mortality Rate    0
# dtype: int64

# %%
df['Type'].fillna(0, inplace=True)
df['Year'].fillna(0, inplace=True)
df['Mortality Rate'].fillna(0, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Type            198 non-null    object
#  1   Year            198 non-null    int64
#  2   Mortality Rate  198 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#              Year  Mortality Rate
# count   198.00000      198.000000
# mean   1964.00000       25.085354
# std      28.64982       21.618767
# min    1915.00000        4.000000
# 25%    1939.25000        7.625000
# 50%    1964.00000       19.100000
# 75%    1988.75000       33.950000
# max    2013.00000      101.000000

# %%
columns = df.columns.tolist()
print(columns)
# Out:
# ['Type', 'Year', 'Mortality Rate']
